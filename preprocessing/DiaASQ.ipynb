# %% [markdown]
# ## Load data

# %%
import os
import pandas as pd

folder_path= 'jsons_en'
source_name='train.json'
File_path=os.path.join(os.getcwd(),folder_path,source_name)
df= pd.read_json(File_path)
df.head(10)
# Out:
#    doc_id                                          sentences  \
# 0       3  [Really ? why I use IQOO9 for so many days tha...
# 1       4  [My brother 's GT2PRO is not as hot as his IQO...
# 2       5  [Can the signal be a bit better ? No signal ev...
# 3       6  [Xiaomi : ..., As a girl , I do n't know what ...
# 4       7  [Then the signal and battery are still short b...
# 5       8  [Four days of crashing three times or four tim...
# 6       9  [Compare to Xiaomi 11 , which is better ?, 11 ...
# 7      10  [It seems that I have a problem with my aesthe...
# 8      13  [Well , what is the situation of P50 ., Xiaomi...
# 9      14  [Completely aligned with reno [ doge ] Even th...
#
#                            replies                        speakers  \
# 0  [-1, 0, 1, 2, 0, 4, 5, 0, 7, 8]  [0, 1, 2, 1, 3, 0, 4, 5, 0, 6]
# 1              [-1, 0, 1, 2, 0, 0]              [0, 1, 0, 1, 2, 3]
# 2  [-1, 0, 1, 2, 0, 4, 5, 0, 7, 8]  [0, 1, 2, 1, 3, 4, 3, 5, 6, 7]
# 3        [-1, 0, 1, 2, 0, 4, 0, 6]        [0, 1, 2, 3, 4, 5, 6, 7]
# 4              [-1, 0, 1, 2, 0, 0]              [0, 1, 2, 3, 3, 4]
# 5  [-1, 0, 1, 2, 0, 4, 5, 0, 7, 8]  [0, 1, 0, 1, 2, 0, 3, 4, 0, 4]
# 6           [-1, 0, 1, 2, 0, 4, 0]           [0, 1, 2, 1, 3, 4, 5]
# 7  [-1, 0, 1, 2, 0, 4, 5, 0, 7, 8]  [0, 1, 0, 1, 2, 3, 2, 4, 5, 4]
# 8              [-1, 0, 1, 2, 0, 4]              [0, 1, 0, 1, 2, 0]
# 9        [-1, 0, 1, 2, 0, 4, 0, 6]        [0, 1, 2, 1, 3, 2, 4, 5]
#
#                                             triplets  \
# 0  [[164, 165, 165, 166, 167, 169, neg, IQOO9, sc...
# 1  [[42, 43, 43, 44, 45, 47, neg, 10PRO, video, n...
# 2  [[212, 213, 9, 10, 8, 9, neg, 12, signal, No],...
# 3  [[20, 21, 46, 47, 48, 50, neg, XiaoMi, power, ...
# 4  [[135, 136, 2, 3, 7, 9, doubt, 13promax, signa...
# 5  [[29, 30, 33, 36, 38, 39, neg, MIX4, photograp...
# 6  [[25, 26, 48, 49, 50, 52, pos, 12, signal, ver...
# 7  [[15, 16, 34, 35, 31, 32, neg, 10PRO, flash, d...
# 8  [[9, 11, 36, 37, 35, 36, neg, Xiaomi wine, bat...
# 9  [[26, 27, 30, 32, 33, 35, pos, Reno7, breathin...
#
#                                              targets  \
# 0  [[5, 6, IQOO9], [96, 97, 9], [112, 113, 865], ...
# 1  [[3, 4, GT2PRO], [10, 11, IQOO7], [17, 19, Xia...
# 2  [[102, 104, Mi 10pro], [139, 141, Xiaomi 10], ...
# 3               [[20, 21, XiaoMi], [94, 95, Xiaomi]]
# 4  [[28, 29, Apple], [38, 40, Apple phone], [66, ...
# 5  [[17, 18, MIX4], [29, 30, MIX4], [121, 123, Mi...
# 6  [[2, 4, Xiaomi 11], [9, 10, 11], [25, 26, 12],...
# 7  [[15, 16, 10PRO], [91, 92, 10pro], [131, 132, ...
# 8  [[7, 8, P50], [9, 11, Xiaomi wine], [77, 78, H...
# 9  [[3, 4, reno], [20, 21, Reno7], [22, 24, Honor...
#
#                                              aspects  \
# 0  [[232, 237, area of the hot plate], [207, 210,...
# 1  [[11, 16, calling for a voice call], [20, 21, ...
# 2  [[9, 10, signal], [168, 169, signal], [264, 26...
# 3                [[46, 47, power], [120, 121, MIUI]]
# 4  [[22, 23, battery], [136, 137, battery], [76, ...
# 5  [[115, 117, photo function], [33, 36, photogra...
# 6  [[63, 64, game], [48, 49, signal], [54, 57, mo...
# 7  [[34, 35, flash], [139, 141, fast charging], [...
# 8                  [[63, 65, 5G], [36, 37, battery]]
# 9  [[103, 105, cost -effectiveness], [129, 130, f...
#
#                                             opinions  \
# 0  [[215, 218, not a level, pos], [177, 178, unho...
# 1  [[45, 47, not hot, neg], [31, 34, not get stuc...
# 2  [[115, 117, not broken, pos], [153, 155, super...
# 3  [[116, 119, too many bugs, neg], [48, 50, drai...
# 4  [[47, 49, very weak, neg], [119, 121, first la...
# 5  [[131, 135, not as bad as, pos], [131, 135, no...
# 6  [[121, 127, 59 frames [Yun Bei], neg], [101, 1...
# 7  [[71, 72, pretty, pos], [18, 19, best, pos], [...
# 8  [[35, 36, small, neg], [2, 6, what is the situ...
# 9  [[62, 63, good, pos], [230, 233, a bit suspend...
#
#                                           dependency  \
# 0  [[0, -1, ROOT, Really, R], [1, -1, ROOT, ?, R]...
# 1  [[0, -1, ROOT, My, R], [1, -1, ROOT, brother, ...
# 2  [[0, -1, ROOT, Can, R], [1, -1, ROOT, the, R],...
# 3  [[0, -1, ROOT, Xiaomi, R], [1, -1, ROOT, :, R]...
# 4  [[0, -1, ROOT, Then, R], [1, -1, ROOT, the, R]...
# 5  [[0, -1, ROOT, Four, R], [1, -1, ROOT, days, R...
# 6  [[0, -1, ROOT, Compare, R], [1, -1, ROOT, to, ...
# 7  [[0, -1, ROOT, It, R], [1, -1, ROOT, seems, R]...
# 8  [[0, -1, ROOT, Well, R], [1, -1, ROOT, ,, R], ...
# 9  [[0, -1, ROOT, Completely, R], [1, -1, ROOT, a...
#
#                                     local_dependency  \
# 0  [[[0, -1, ROOT, Really, R], [1, -1, ROOT, ?, R...
# 1  [[[0, -1, ROOT, My, R], [1, -1, ROOT, brother,...
# 2  [[[0, -1, ROOT, Can, R], [1, -1, ROOT, the, R]...
# 3  [[[0, -1, ROOT, Xiaomi, R], [1, -1, ROOT, :, R...
# 4  [[[0, -1, ROOT, Then, R], [1, -1, ROOT, the, R...
# 5  [[[0, -1, ROOT, Four, R], [1, -1, ROOT, days, ...
# 6  [[[0, -1, ROOT, Compare, R], [1, -1, ROOT, to,...
# 7  [[[0, -1, ROOT, It, R], [1, -1, ROOT, seems, R...
# 8  [[[0, -1, ROOT, Well, R], [1, -1, ROOT, ,, R],...
# 9  [[[0, -1, ROOT, Completely, R], [1, -1, ROOT, ...
#
#                                          sub_dialogs
# 0  [{'doc_id': '0003_0', 'sentences': ['Really ? ...
# 1  [{'doc_id': '0004_0', 'sentences': ['My brothe...
# 2  [{'doc_id': '0005_0', 'sentences': ['Can the s...
# 3  [{'doc_id': '0006_0', 'sentences': ['Xiaomi : ...
# 4  [{'doc_id': '0007_0', 'sentences': ['Then the ...
# 5  [{'doc_id': '0008_0', 'sentences': ['Four days...
# 6  [{'doc_id': '0009_0', 'sentences': ['Compare t...
# 7  [{'doc_id': '0010_0', 'sentences': ['It seems ...
# 8  [{'doc_id': '0013_0', 'sentences': ['Well , wh...
# 9  [{'doc_id': '0014_0', 'sentences': ['Completel...

# %%
triplets = list(df.loc[0, 'sub_dialogs'])
for r in triplets:
   print('----------------------------------------------------------------')
   sentences=r.get('sentences')
   triplets=r.get('triplets')
   
   print(sentences)
   print(triplets)
   print(f'triplets:{len(triplets)}')
   print(f'sentences:{len(sentences)}')
# Out:
# ----------------------------------------------------------------
# ['Really ? why I use IQOO9 for so many days that I feel very fragrant .', 'If you really listen to digital bloggers , you can only buy that kind of cost - effective machine , but does everyone need it ? Does everyone play Yuanshen ?', 'Ah , is there still a cost -effective machine for the recent machine ? Is not all the hardware shrinks more than last year , the price rises ? [ laugh haha ] .', 'The sub -brand is basically cost - effective ( the pile last year ) .']
# [[5, 6, -1, -1, 13, 15, 'pos', 'IQOO9', '', 'very fragrant']]
# triplets:1
# sentences:4
# ----------------------------------------------------------------
# ['Really ? why I use IQOO9 for so many days that I feel very fragrant .', '9 with DC is definitely fragrant but you try again in summer .', 'In summer , 865 , 870 and A13 A14 are all fever [ sweat ] .', "What if the fever ? at least the game experience has stabilized at high frame rate , 90 or even 120 , TM 's 888 and 8gen1 is barely 60Hz , and it 's even hotter than others"]
# [[16, 17, 53, 55, 56, 60, 'pos', '9', 'game experience', 'stabilized at high frame'], [5, 6, -1, -1, 13, 15, 'pos', 'IQOO9', '', 'very fragrant'], [16, 17, -1, -1, 21, 22, 'pos', '9', '', 'fragrant'], [32, 33, -1, -1, 40, 41, 'neg', '865', '', 'fever'], [34, 35, -1, -1, 40, 41, 'neg', '870', '', 'fever'], [36, 37, -1, -1, 40, 41, 'neg', 'A13', '', 'fever'], [37, 38, -1, -1, 40, 41, 'neg', 'A14', '', 'fever']]
# triplets:7
# sentences:4
# ----------------------------------------------------------------
# ['Really ? why I use IQOO9 for so many days that I feel very fragrant .', "Your IQOO9 scheduling is quite conservative . My colleague 's Xiaomi Mi 12Pro is unhot every day . The manufacturers are conservatively scheduled . When running for a long time , the large nuclear frequency is extremely low [ DOGE ] .", "IQOO9 's heat dissipation stack and Xiaomi Mi 12Pro are not a level at all [ laughs without speaking ] .", "It 's almost okay , the area of the hot plate is almost the same ."]
# [[17, 18, 18, 19, 20, 22, 'neg', 'IQOO9', 'scheduling', 'quite conservative'], [58, 59, 60, 63, 68, 71, 'neg', 'IQOO9', 'heat dissipation stack', 'not a level'], [58, 59, 60, 63, 81, 83, 'neu', 'IQOO9', 'heat dissipation stack', 'almost okay'], [58, 59, 85, 90, 91, 92, 'neu', 'IQOO9', 'area of the hot plate', 'almost'], [26, 29, 38, 39, 37, 38, 'neg', 'Xiaomi Mi 12Pro', 'scheduled', 'conservatively'], [65, 67, 60, 63, 68, 71, 'pos', 'Mi 12Pro', 'heat dissipation stack', 'not a level'], [26, 29, 48, 51, 52, 54, 'neg', 'Xiaomi Mi 12Pro', 'large nuclear frequency', 'extremely low'], [5, 6, -1, -1, 13, 15, 'pos', 'IQOO9', '', 'very fragrant'], [26, 29, -1, -1, 30, 31, 'pos', 'Xiaomi Mi 12Pro', '', 'unhot']]
# triplets:9
# sentences:4

# %%
sentences = list(df.loc[0, 'sentences'])
triplets = list(df.loc[0, 'triplets'])
for t in triplets:
    print(t)
# Out:
# [164, 165, 165, 166, 167, 169, 'neg', 'IQOO9', 'scheduling', 'quite conservative']
# [205, 206, 207, 210, 215, 218, 'neg', 'IQOO9', 'heat dissipation stack', 'not a level']
# [205, 206, 207, 210, 228, 230, 'neu', 'IQOO9', 'heat dissipation stack', 'almost okay']
# [205, 206, 232, 237, 238, 239, 'neu', 'IQOO9', 'area of the hot plate', 'almost']
# [96, 97, 133, 135, 136, 140, 'pos', '9', 'game experience', 'stabilized at high frame']
# [173, 176, 185, 186, 184, 185, 'neg', 'Xiaomi Mi 12Pro', 'scheduled', 'conservatively']
# [212, 214, 207, 210, 215, 218, 'pos', 'Mi 12Pro', 'heat dissipation stack', 'not a level']
# [173, 176, 195, 198, 199, 201, 'neg', 'Xiaomi Mi 12Pro', 'large nuclear frequency', 'extremely low']
# [5, 6, -1, -1, 13, 15, 'pos', 'IQOO9', '', 'very fragrant']
# [173, 176, -1, -1, 177, 178, 'pos', 'Xiaomi Mi 12Pro', '', 'unhot']
# [96, 97, -1, -1, 101, 102, 'pos', '9', '', 'fragrant']
# [112, 113, -1, -1, 120, 121, 'neg', '865', '', 'fever']
# [114, 115, -1, -1, 120, 121, 'neg', '870', '', 'fever']
# [116, 117, -1, -1, 120, 121, 'neg', 'A13', '', 'fever']
# [117, 118, -1, -1, 120, 121, 'neg', 'A14', '', 'fever']

# %% [markdown]
# ## explore data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Extract sentences from the DATAFRAME
sentences = df['sentences'].tolist()
text=""
for s in sentences:
   text += ' ' + ' '.join(s)
# # Function to preprocess text and remove non-alphabet characters
# def preprocess_text(text):
#     text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove non-alphabet characters
#     return text

# # Preprocess the sentences
# preprocessed_sentences = [preprocess_text(sentence) for sentence in sentences]
# Join the preprocessed sentences into a single string


# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Plot the WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud for Sentences')
plt.axis('off')
plt.show()

# %%
count_null = df['sentences'].isna().sum()  # or df['Column1'].isnull().sum()
print("Total null count in 'sentences':", count_null)
count_null = df['triplets'].isna().sum()  # or df['Column1'].isnull().sum()
print("Total null count in 'triplets':", count_null)
# Out:
# Total null count in 'sentences': 0
# Total null count in 'triplets': 0

# %%
# Function to preprocess text and remove non-alphabet characters

# following the ASTE format, [a, s, o ] [[spot A][Spot s],o]
def remove_specific_special_chars(text):
    with open('special_characters.txt', 'r') as file:
      chars_to_remove = [line.strip() for line in file]
    try:
        new_text=text
        for char in chars_to_remove:
            new_text = new_text.replace(char, '')
        return new_text
    except: return text
# Read the special characters from the text file

# Remove specific special characters from the text
# text ="2312387y12312]3[12p]312ejasdncdfc[][/*-+]"
# cleaned_text = remove_specific_special_chars(text, chars_to_remove)
def assign_positions_to_paragraphs(paragraphs, triplets):
    result = []
    categories =[]
    for p in paragraphs:
      assigned_targets = []
      for t in triplets:
          # index = transfer(t[0])
          # count = transfer(t[1])
          aspect = t[7]
          sentiment= t[6]
          category = t[8]
          opinion = t[9]
          cleaned_string=remove_specific_special_chars(p)
          _op=cleaned_string.replace(opinion, "~op/ "+opinion+" ~op/")
          _as=cleaned_string.replace(aspect, "~as/ "+aspect+" ~as/")
        
          _as_index =[]
          _op_index =[]
          for ind,val in enumerate(_op.split()):
              if val =="~op/":
                  _op_index.append(ind)
          for ind,val in enumerate(_as.split()):
              if val == "~as/":
                  _as_index.append(ind)
          try:
            _opinion=[i for i in range(_op_index[0],_op_index[1]-1) ]
            _aspect=[i for i in range(_as_index[0] ,_as_index[1]-1) ]
            # print(f"{_op.split()},{_opinion} ")
            # print(f"{_op.split()},{_opinion} ")
            # print(f"opinion: {opinion},aspect:{aspect}")
            if sentiment !="" and sentiment != -1:
              assigned_targets.append((_aspect,_opinion,sentiment))
              categories.append(category)
            #   print(f"{cleaned_string}, [{_aspect},{_opinion},{sentiment}]")
          except: continue
      if len(assigned_targets)>0:
        result.append([cleaned_string, assigned_targets])
      assigned_targets = []
    categories= list(set(categories ))
    return result

# %%
sentences = list(df.loc[0, 'sentences'])
triplets = list(df.loc[0, 'triplets'])

result = assign_positions_to_paragraphs(sentences,triplets)
for r in result:
   print (r)
# for c in result:
#    print (c)
# Out:
# ['Really ? why I use IQOO9 for so many days that I feel very fragrant .', [([5], [13, 14], 'pos')]]
# ['9 with DC is definitely fragrant but you try again in summer .', [([0], [5], 'pos')]]
# ['In summer , 865 , 870 and A13 A14 are all fever  sweat  .', [([3], [11], 'neg'), ([5], [11], 'neg'), ([7], [11], 'neg'), ([8], [11], 'neg')]]
# ['Your IQOO9 scheduling is quite conservative . My colleague s Xiaomi Mi 12Pro is unhot every day . The manufacturers are conservatively scheduled . When running for a long time , the large nuclear frequency is extremely low  DOGE  .', [([1], [4, 5], 'neg'), ([10, 11, 12], [21], 'neg'), ([10, 11, 12], [36, 37], 'neg'), ([10, 11, 12], [14], 'pos')]]
# ['IQOO9 s heat dissipation stack and Xiaomi Mi 12Pro are not a level at all  laughs without speaking  .', [([0], [10, 11, 12], 'neg'), ([7, 8], [10, 11, 12], 'pos')]]

# %%
import json
sentences = list(df.loc[0, 'sentences'])
triplets = list(df.loc[0, 'triplets'])

result,categories = assign_positions_to_paragraphs(sentences,triplets)
# for r in result:
#    print (r)
for c in categories:
   print (c)

# Save the list as a JSON string in the text file
with open('categories.txt', 'w') as file:
    json.dump(categories, file)
# Out:
# scheduled
# scheduling
# game experience
# heat dissipation stack
# large nuclear frequency
# area of the hot plate

# %%
def assign_positions_to_paragraphs(paragraphs, triplets):
    # global unique_categories,unique_sentiments
    result = []
    spot=0
    for p in paragraphs:
      assigned_targets = []
      for t in triplets:
          index = t[0]
          count = t[1]
          aspect = t[7] if t[7] !="" else 'NULL'
          sentiment= t[6] if t[6] !="" else 'NULL'
          # unique_sentiments.append(sentiment)
          category = t[8] if t[8] !="" else 'NULL'
          opinion = t[9] if t[9] !="" else 'NULL'
          count=count-index if count-index>0 else count
          if (index-spot) < len(p.split()) and (index-spot)>=0 and(aspect!= -1 and sentiment!= -1 and category!= -1 and opinion!= -1 ) and(sentiment not in [ 'doubt', 'amb', 'neu']) :
            merged_elements = ' '.join(p.split()[index-spot:index-spot + count]).replace(',','').strip()
            new_s=p.split()
            
            del new_s[index-spot:index-spot + count]
            new_s.insert(index-spot, merged_elements)
            # Process the current paragraph
            try:
              if new_s.index(aspect)==(index-spot):
                aspect=remove_specific_special_chars(aspect)
                category=remove_specific_special_chars(category)
                # if category !='NULL': unique_categories.append(category)
                sentiment=remove_specific_special_chars(sentiment)
                opinion=remove_specific_special_chars(opinion)
                assigned_targets.append([aspect,category,sentiment,opinion])
            except:
                aspect=remove_specific_special_chars(aspect)
                category=remove_specific_special_chars(category)
                # if category !='NULL': unique_categories.append(category)
                sentiment=remove_specific_special_chars(sentiment)
                opinion=remove_specific_special_chars(opinion)
                assigned_targets.append(['NULL',category,sentiment,opinion])
          
      spot += len(p.split())
      # Append the paragraph with its assigned positions
      cleaned_string=remove_specific_special_chars(p)
      result.append([cleaned_string, assigned_targets])
      assigned_targets = []
    return result

def list_to_string(lst):
    return str(lst)

# %%
my_list=list(df.apply(lambda row: assign_positions_to_paragraphs(row['sentences'], row['triplets']), axis=1))
# Apply the function to each row and store the result in a new column
# Flatten the nested list using list comprehension
flattened_list = [(item[0], item[1]) for sublist in my_list for item in sublist]

# Create a DataFrame
final_result = pd.DataFrame(flattened_list, columns=['Sentence', 'Triplets'])
# clean up empty rows
count_empty_lists = (final_result['Triplets'].apply(lambda x: len(x) == 0)).sum()
print("Number of rows with empty lists in 'Triplets':", count_empty_lists)
final_result = final_result[final_result['Triplets'].apply(lambda x: len(x) > 0)]
# Out:
# Number of rows with empty lists in 'Triplets': 3434

# %%
view_final_result =final_result

# Explode the "triples" column into separate rows
view_final_result = view_final_result.explode('Triplets', ignore_index=True)
# Create new columns for each element in the tuple
view_final_result[['aspect', 'category', 'sentiment', 'opinion']] = pd.DataFrame(view_final_result['Triplets'].tolist(), index=view_final_result.index)
# Drop the original "triples" column
view_final_result = view_final_result.drop('Triplets', axis=1)
# Reset the index
view_final_result = view_final_result.reset_index(drop=True)
view_final_result
# Out:
#                                                Sentence aspect  \
# 0     Really ? why I use IQOO9 for so many days that...  IQOO9
# 1     9 with DC is definitely fragrant but you try a...      9
# 2     9 with DC is definitely fragrant but you try a...      9
# 3     In summer , 865 , 870 and A13 A14 are all feve...    865
# 4     In summer , 865 , 870 and A13 A14 are all feve...    870
# ...                                                 ...    ...
# 5335      Is the endurance of S22 better than 13 mini ?    S22
# 5336      Is the endurance of S22 better than 13 mini ?    S22
# 5337      Is the endurance of S22 better than 13 mini ?   mini
# 5338  At 60hz , the battery life is definitely bette...   mini
# 5339   I does nt know 13mini , S22 has a fuck endurance    S22
#
#              category sentiment                   opinion
# 0                NULL       pos             very fragrant
# 1     game experience       pos  stabilized at high frame
# 2                NULL       pos                  fragrant
# 3                NULL       neg                     fever
# 4                NULL       neg                     fever
# ...               ...       ...                       ...
# 5335        telephoto       pos                    better
# 5336        endurance       neg              cant compare
# 5337        endurance       pos              cant compare
# 5338     battery life       neg                    better
# 5339        endurance       neg                      fuck
#
# [5340 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
columns_to_plot = ['aspect', 'category', 'sentiment', 'opinion']

fig, axes = plt.subplots(2, 2, figsize=(10, 8))
fig.suptitle("Histograms")
# fig.autofmt_xdate(rotation=45,)
for i, column in enumerate(columns_to_plot):
    row, col = divmod(i, 2)
    ax = axes[row, col]
    
    ax.hist(view_final_result[column].dropna(), bins=10, alpha=0.75)
    ax.set_title(f'Histogram of {column}')
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')
    # Customize the x-axis labels
    ax.xaxis.set_major_locator(MaxNLocator(integer=True, prune='both'))
    ax.tick_params(axis='x', labelrotation=45, labelsize=8)
plt.tight_layout()
plt.subplots_adjust(top=0.9)
plt.show()

# %%
def remove_specific_special_chars(text, chars_to_remove):
    try:
        new_text=text
        for char in chars_to_remove:
            new_text = new_text.replace(char, '')
        return new_text
    except: return text
# Read the special characters from the text file
with open('special_characters.txt', 'r') as file:
    chars_to_remove = [line.strip() for line in file]
# Remove specific special characters from the text
text ="2312387y12312]3[12p]312ejasdncdfc[][/*-+]"
cleaned_text = remove_specific_special_chars(text, chars_to_remove)

print("Cleaned text:", cleaned_text)
# Out:
# Cleaned text: 2312387y12312312p312ejasdncdfc

# %%
# find special characters
import string, os
cur_path = os.getcwd()
print(cur_path)
def find_special_characters(text):
    special_characters = []
    
    for char in text:
        if char not in string.ascii_letters and char not in string.digits and char not in string.whitespace:
            special_characters.append(char)
    return special_characters
spec_folder_path= os.path.join(cur_path,'jsons_en')
Spec_Folder_path=os.path.join(os.getcwd(),spec_folder_path)
file_paths = [os.path.join(Spec_Folder_path, filename) for filename in os.listdir(Spec_Folder_path) if os.path.isfile(os.path.join(Spec_Folder_path, filename))]
special_chars =[]
for path in file_paths:
    print(f"path:{path}")
    spec_df= pd.read_json(path)
    spec_sentences = spec_df['sentences'].tolist()
    text=""
    for s in sentences:
        text += ' ' + ' '.join(s)
    special_chars=special_chars+ find_special_characters(text)
unique_special_chars = list(set(special_chars))
print("Special characters found:", special_chars)
# Store the special characters in a text file
with open('special_characters.txt', 'w') as file:
    file.write('\n'.join(unique_special_chars))
# Out:
# /home/hkhnhan/KHMT/VBUD/DiaASQ
# path:/home/hkhnhan/KHMT/VBUD/DiaASQ/jsons_en/valid.json
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/hkhnhan/KHMT/VBUD/DiaASQ/DiaASQ.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/home/hkhnhan/KHMT/VBUD/DiaASQ/DiaASQ.ipynb#X12sZmlsZQ%3D%3D?line=15'>16</a> for path in file_paths:
#      <a href='vscode-notebook-cell:/home/hkhnhan/KHMT/VBUD/DiaASQ/DiaASQ.ipynb#X12sZmlsZQ%3D%3D?line=16'>17</a>     print(f"path:{path}")
# ---> <a href='vscode-notebook-cell:/home/hkhnhan/KHMT/VBUD/DiaASQ/DiaASQ.ipynb#X12sZmlsZQ%3D%3D?line=17'>18</a>     spec_df= pd.read_json(path)
#      <a href='vscode-notebook-cell:/home/hkhnhan/KHMT/VBUD/DiaASQ/DiaASQ.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a>     spec_sentences = spec_df['sentences'].tolist()
#      <a href='vscode-notebook-cell:/home/hkhnhan/KHMT/VBUD/DiaASQ/DiaASQ.ipynb#X12sZmlsZQ%3D%3D?line=19'>20</a>     text=""
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Code and test cases

# %%
result_df = pd.DataFrame()
my_list=list(df.apply(lambda row: assign_positions_to_paragraphs(row['sentences'], row['triplets']), axis=1))
# Create a new DataFrame to store the results
result_df = pd.DataFrame(columns=['sentence', 'ABSA'])
for sub_list in my_list:
    for data in sub_list:
        _result_df=pd.DataFrame({'sentence': [data[0]], 'ABSA': [data[1]]})
        # result_df[['sentence',"ABSA"]]=pd.DataFrame(data)
        result_df=pd.concat([result_df,_result_df])
result_df

def list_to_string(lst):
    return str(lst)
result_df['Formated'] = result_df['sentence'] + '####'+result_df['ABSA'].apply(list_to_string)
result_df.head(10)
# Out:
#                                             sentence  \
# 0  Really ? why I use IQOO9 for so many days that...
# 0  9 with DC is definitely fragrant but you try a...
# 0  In summer , 865 , 870 and A13 A14 are all feve...
# 0  Your IQOO9 scheduling is quite conservative . ...
# 0  IQOO9 s heat dissipation stack and Xiaomi Mi 1...
# 0  My brother s GT2PRO is not as hot as his IQOO7...
# 0  10PRO video is not hot ? Is there a mobile pho...
# 0  10Pro s back cover is broken , still holding o...
# 0  In addition to being able to split the screen ...
# 0  Haha real , Xiaomi 10 I changed from Apple is ...
#
#                                                 ABSA  \
# 0                             [([5], [13, 14], pos)]
# 0                                  [([0], [5], pos)]
# 0  [([3], [11], neg), ([5], [11], neg), ([7], [11...
# 0  [([1], [4, 5], neg), ([10, 11, 12], [21], neg)...
# 0  [([0], [10, 11, 12], neg), ([7, 8], [10, 11, 1...
# 0  [([29], [22, 23], neg), ([17, 18], [22, 23], p...
# 0           [([0], [3, 4], neg), ([0], [3, 4], pos)]
# 0                                 [([0], [12], pos)]
# 0  [([12, 13], [25, 26], pos), ([12, 13], [33], p...
# 0  [([3, 4], [17, 18], pos), ([8], [39, 40, 41, 4...
#
#                                             Formated
# 0  Really ? why I use IQOO9 for so many days that...
# 0  9 with DC is definitely fragrant but you try a...
# 0  In summer , 865 , 870 and A13 A14 are all feve...
# 0  Your IQOO9 scheduling is quite conservative . ...
# 0  IQOO9 s heat dissipation stack and Xiaomi Mi 1...
# 0  My brother s GT2PRO is not as hot as his IQOO7...
# 0  10PRO video is not hot ? Is there a mobile pho...
# 0  10Pro s back cover is broken , still holding o...
# 0  In addition to being able to split the screen ...
# 0  Haha real , Xiaomi 10 I changed from Apple is ...

# %%
formated=str(result_df.loc[0, 'Formated'])
print(formated)
# Out:
# 0    Really ? why I use IQOO9 for so many days that...
# 0    9 with DC is definitely fragrant but you try a...
# 0    In summer , 865 , 870 and A13 A14 are all feve...
# 0    Your IQOO9 scheduling is quite conservative . ...
# 0    IQOO9 s heat dissipation stack and Xiaomi Mi 1...
#                            ...
# 0    In terms of hand feel , S20 exceeds him by 20 ...
# 0    Is the endurance of S22 better than 13 mini ?#...
# 0    At 60hz , the battery life is definitely bette...
# 0    Is the 60 better than the iPhone 60 ? I just r...
# 0    I does nt know 13mini , S22 has a fuck enduran...
# Name: Formated, Length: 2568, dtype: object

# %%
folder_path= 'text_dataset_formated'
if not os.path.exists(os.path.join(os.getcwd(),folder_path)):
    os.makedirs(folder_path)
source_name='train.txt'
output_json_file=os.path.join(os.getcwd(),folder_path,source_name)
result_df['Formated'].to_csv(output_json_file, sep='\t', index=False, header=False)
os.path.basename(output_json_file)
# Out:
# 'train.txt'

# %%
senttag2opinion = {'pos': 'great', 'neg': 'bad', 'neu': 'ok'}
sentword2opinion = {'positive': 'great', 'negative': 'bad', 'neutral': 'ok'}
def get_task_tuple(_tuple, task):
    if task in ["asqp", "acos","diaasq"]:
        at, ac, sp, ot = _tuple
    # try:
        if sp:
            sp = sentword2opinion[sp.lower()] if sp in sentword2opinion else senttag2opinion[sp.lower()]  # 'POS' -> 'good'
    # except:
    #     print(sp)
        if at and at.lower() == 'null':  # for implicit aspect term
            at = 'it'

        return at, ac, sp, ot

def get_para_targets(sents, labels, task):
    """
    Obtain the target sentence under the paraphrase paradigm
    """
    for i in range(len(sents)):
        label = labels[i]
        # at, ac, sp, ot
        if len(label) > 1:
            for _tuple in label:
                at, sp, ot = get_task_tuple(_tuple, task)
                ac =None
            print(at, sp, ot)
            

def read_line_examples_from_file(data_path,
                                 task_name,
                                 data_name,
                                 lowercase,
                                 silence=True):
    """
    Read data from file, each line is: sent####labels
    Return List[List[word]], List[Tuple]
    """
    tasks, datas = [], []
    sents, labels = [], []
    with open(data_path, 'r', encoding='UTF-8') as fp:
        words, labels = [], []
        for line in fp:
            line = line.strip()
            if lowercase:
                line = line.lower()
            if "unified" in task_name:
                _task, _data, line = line.split("\t")
                tasks.append(_task)
                datas.append(_data)
            else:
                tasks.append(task_name)
                datas.append(data_name)
            if line != '':
                words, tuples = line.split('####')
                sents.append(words.split())
                labels.append(eval(tuples))
    if silence:
        print(f"Total examples = {len(sents)}")
    return tasks, datas, sents, labels
data_path='multi-view-prompting-main/data/diaasq/phone/dev.txt'
tasks, datas, sents, labels=read_line_examples_from_file(data_path,"diasq","phone", False)
sents = [s.copy() for s in sents]
new_inputs, targets = [], []
for task, data, sent, label in zip(tasks, datas, sents, labels):
    new_input, target = get_para_targets([sent], [label], task)
# Out:
# Total examples = 314
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/hkhnhan/Code/VBUD/DiaASQ/DiaASQ.ipynb Cell 18 line 6
#      <a href='vscode-notebook-cell:/Users/hkhnhan/Code/VBUD/DiaASQ/DiaASQ.ipynb#X31sZmlsZQ%3D%3D?line=63'>64</a> new_inputs, targets = [], []
#      <a href='vscode-notebook-cell:/Users/hkhnhan/Code/VBUD/DiaASQ/DiaASQ.ipynb#X31sZmlsZQ%3D%3D?line=64'>65</a> for task, data, sent, label in zip(tasks, datas, sents, labels):
# ---> <a href='vscode-notebook-cell:/Users/hkhnhan/Code/VBUD/DiaASQ/DiaASQ.ipynb#X31sZmlsZQ%3D%3D?line=65'>66</a>     new_input, target = get_para_targets([sent], [label], task)
#
# /Users/hkhnhan/Code/VBUD/DiaASQ/DiaASQ.ipynb Cell 18 line 2
#      <a href='vscode-notebook-cell:/Users/hkhnhan/Code/VBUD/DiaASQ/DiaASQ.ipynb#X31sZmlsZQ%3D%3D?line=22'>23</a> if len(label) > 1:
#      <a href='vscode-notebook-cell:/Users/hkhnhan/Code/VBUD/DiaASQ/DiaASQ.ipynb#X31sZmlsZQ%3D%3D?line=23'>24</a>     for _tuple in label:
# ---> <a href='vscode-notebook-cell:/Users/hkhnhan/Code/VBUD/DiaASQ/DiaASQ.ipynb#X31sZmlsZQ%3D%3D?line=24'>25</a>         at, sp, ot = get_task_tuple(_tuple, task)
#      <a href='vscode-notebook-cell:/Users/hkhnhan/Code/VBUD/DiaASQ/DiaASQ.ipynb#X31sZmlsZQ%3D%3D?line=25'>26</a>         ac =None
#      <a href='vscode-notebook-cell:/Users/hkhnhan/Code/VBUD/DiaASQ/DiaASQ.ipynb#X31sZmlsZQ%3D%3D?line=26'>27</a>     print(at, sp, ot)
#
# TypeError: cannot unpack non-iterable NoneType object
